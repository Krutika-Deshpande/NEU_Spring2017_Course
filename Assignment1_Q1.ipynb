# %% [markdown]
# #Question 1
# Under package Gutenberg, see what files are in it.
# Find out how many words and how many unique words in file 'austen-persuasion.txt'.
# Calculate the frequency for each words and show the top 10 most frequent words and their frequency.Try NOT to use FreqDist module.
# Keep the punctuation and stop words in this question.

# %%
import nltk

# %%
nltk.corpus.gutenberg.fileids() #files in the Gutenberg package
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
NumberOfWords = nltk.corpus.gutenberg.words('austen-persuasion.txt') # number of words in austen.persuasion.txt
len(NumberOfWords)
# Out:
# 98171

# %%
print(NumberOfWords)
NumberOfUniqueWords = set(NumberOfWords) # set function is used to find number of unique words
print('The number of unique words in the austen-persuasion.txt' +  'are' + ' ' + str(len(NumberOfUniqueWords)))
# Out:
# ['[', 'Persuasion', 'by', 'Jane', 'Austen', '1818', ...]
# The number of unique words in the austen-persuasion.txtare 6132

# %%
from collections import Counter
words = nltk.corpus.gutenberg.words('austen-persuasion.txt')
freqs = Counter(words)   # using counter method from collections to find the frequency of words in the given text
print('The frequency of each word in the austen-persuasion.txt is  ' +  str(freqs))
# Out:
# The frequency of each word in the austen-persuasion.txt is  Counter({',': 6750, 'the': 3120, 'to': 2775, '.': 2741, 'and': 2739, 'of': 2564, 'a': 1529, 'in': 1346, 'was': 1330, ';': 1290, 'had': 1177, 'her': 1159, 'I': 1124, 'be': 949, 'not': 926, 'it': 857, 'that': 853, 'she': 819, '"': 793, 'as': 787, 'he': 736, 'for': 695, 'with': 643, 'his': 625, 'have': 583, 'but': 553, 'you': 548, "'": 525, 'at': 519, 'all': 517, 'Anne': 497, 'been': 496, 's': 485, 'him': 467, 'could': 444, 'were': 426, 'very': 425, 'which': 415, 'by': 411, 'is': 393, 'on': 386, '."': 369, 'would': 351, 'so': 338, 'She': 327, 'they': 323, 'no': 309, '-': 308, 'Captain': 297, 'Mrs': 291, 'from': 290, 'Elliot': 288, 'or': 274, 'their': 273, 'them': 270, 'more': 269, 'Mr': 256, '!': 253, 'than': 243, 'an': 238, 'must': 228, 'He': 225, 'one': 221, 'being': 220, 'Wentworth': 218, 'there': 216, 'only': 214, ',"': 213, 'The': 209, 'much': 205, 'this': 200, 'any': 198, 'such': 196, 'when': 196, 'my': 194, 'Lady': 191, 'do': 190, 'me': 188, 'who': 186, 'should': 185, 'It': 181, 'good': 181, 'little': 175, 'said': 173, 'what': 172, 'Charles': 166, 'might': 166, 'own': 163, 'if': 162, 'will': 162, 'herself': 158, 'did': 157, 'never': 153, 'time': 151, 'think': 149, 'Russell': 148, 'now': 144, 'Sir': 144, 'other': 142, 'are': 141, 'Walter': 141, 'well': 141, 'Mary': 138, 'am': 137, 'some': 135, 'man': 133, 'again': 131, 'nothing': 131, 'Musgrove': 130, 'know': 127, 'too': 127, ':': 124, 'Miss': 123, 'see': 123, '?': 122, 'most': 122, 'soon': 121, 'father': 117, 'great': 116, 'before': 113, 'two': 112, 'your': 112, 'first': 112, 'But': 111, 'Louisa': 111, 'They': 110, 'we': 110, 'quite': 110, 'always': 109, 'though': 107, 'without': 106, '--': 104, 'can': 100, 'has': 100, 'Bath': 99, 'into': 98, 'made': 96, 'every': 96, 'about': 96, 'long': 95, 'out': 95, 'himself': 95, 'say': 93, 'seemed': 93, 'up': 90, 'having': 90, 'thought': 90, 'Elizabeth': 89, 'last': 88, '?"': 88, 'how': 88, 'better': 87, 'may': 87, 'go': 87, 'make': 87, 'over': 84, 'same': 84, 'many': 83, 'friend': 83, 'young': 83, 'home': 83, 'however': 83, 'found': 83, 'sister': 82, 'like': 80, 'You': 80, 'felt': 80, 'family': 79, 'way': 78, 'ever': 78, 'house': 78, 'away': 78, 'Uppercross': 77, 'day': 77, 'give': 77, 'after': 77, 'feelings': 75, 'room': 75, 'Harville': 75, 'Henrietta': 74, 'done': 74, 'sure': 73, 'come': 72, 'its': 72, 'still': 72, 'Kellynch': 72, 'enough': 71, 'moment': 71, 'those': 71, 'Benwick': 70, 'There': 70, 'off': 69, '(': 69, 'back': 69, 'Smith': 68, 'even': 67, 'came': 67, 'Lyme': 67, 'woman': 67, 'A': 66, 'Clay': 66, 'going': 65, 'Admiral': 65, 'just': 65, 'heard': 65, 'present': 65, 'upon': 64, 'mind': 64, 'happy': 63, 'our': 62, 'another': 62, 'party': 62, 'And': 62, 'few': 61, 'something': 61, 'down': 61, '!"': 61, 'knew': 61, 'acquaintance': 61, 'rather': 60, 'then': 60, 'almost': 60, 'Croft': 58, 'wish': 58, 'half': 58, 'while': 58, 'years': 58, 'seen': 58, 'morning': 58, 'evening': 55, 'shall': 55, 'yet': 55, 'look': 54, 'others': 54, 'together': 54, 'between': 53, 'Oh': 53, 'hope': 53, 'indeed': 52, 'ought': 52, 'once': 52, 'gone': 51, 'saw': 51, 'till': 50, 'place': 50, 'take': 50, 'This': 50, 'perhaps': 50, 'life': 49, 'character': 49, 'dear': 49, 'us': 48, 'poor': 48, 'left': 48, 'known': 48, 'anything': 48, 'here': 47, 'No': 47, 'short': 47, 'cried': 47, 'believe': 47, 'side': 47, 'where': 46, 'wife': 45, 'Her': 45, 'looking': 45, 'near': 45, 'We': 45, 'possible': 45, 'certainly': 44, 'leave': 44, 'best': 44, 'feel': 44, 'under': 44, 'right': 43, 'since': 43, 'In': 43, 'these': 43, 'interest': 43, 'really': 43, 'manner': 43, 'old': 43, 'perfectly': 43, 'deal': 43, 'love': 42, 'mother': 42, 'heart': 42, 'cannot': 42, 'least': 42, 'part': 42, 'whole': 42, 'looked': 42, 'course': 42, 'sort': 41, 'name': 41, 'next': 41, 'Musgroves': 41, 'spirits': 41, 'thing': 41, 'each': 41, 'If': 40, 'idea': 40, 'passed': 40, 'nor': 40, 'does': 39, 'people': 39, 'pleasure': 39, 'three': ...

# %%
tenMostFrequent = Counter(words).most_common(10) # using most_common method to find the top 10 frequent words including punctuation and stop words 
print('The top 10 most frequent words and their frequency is  ' + str(tenMostFrequent))
# Out:
# The top 10 most frequent words and their frequency is  [(',', 6750), ('the', 3120), ('to', 2775), ('.', 2741), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), (';', 1290)]
